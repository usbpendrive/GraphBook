# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 45.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6718, done.
# remote: Total 6718 (delta 0), reused 0 (delta 0), pack-reused 6718 (from 1)
# Receiving objects: 100% (6718/6718), 33.26 MiB | 22.08 MiB/s, done.
# Resolving deltas: 100% (3874/3874), done.
# /content/Fooocus

# %%
# !aria2c -o models/loras/ColoringBookRedmond-ColoringBook-ColoringBookAF.safetensors https://civitai.com/api/download/models/136348?type=Model&format=SafeTensor
# Out:
# 11/11 02:53:11 [NOTICE] Downloading 1 item(s)
#
# 11/11 02:53:12 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/2211721/model/murderDronesv1r.GOE0.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Murder-DronesV1R.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20241111/us-east-1/s3/aws4_request&X-Amz-Date=20241111T025312Z&X-Amz-SignedHeaders=host&X-Amz-Signature=7e508f7df8675ee4011a7c3b9861a1109e996a341f4e8c313509acaf6d1c4c28
#
# 11/11 02:53:12 [NOTICE] Download complete: /content/Fooocus/models/loras/ColoringBookRedmond-ColoringBook-ColoringBookAF.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f06ed1|OK  |    40MiB/s|/content/Fooocus/models/loras/ColoringBookRedmond-ColoringBook-ColoringBookAF.safetensors
#
# ...

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 7.83MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 7.70MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 41.5MB/s]
# ...
